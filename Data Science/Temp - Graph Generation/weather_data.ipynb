# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
import sys
import cartopy.crs as ccrs

from cartopy.mpl.gridliner import LATITUDE_FORMATTER, LONGITUDE_FORMATTER
from cartopy.io.shapereader import Reader
from cartopy.feature import ShapelyFeature

# %%
weather_data_raw = pd.read_csv("EOG-Resources-Dataset-main/weather_data.csv")
weather_data_raw = weather_data_raw.iloc[:, 1:]
pd.set_option("display.max_columns", 15)
weather_data_raw.insert(0, "Time", np.arange(weather_data_raw.shape[0]))
weather_data_raw.columns = ["Time", "Barometric Pressure", "Humidity", "Temperature", "Wind Direction", "Wind Speed"]
weather_data_raw.describe()
# Out:
#                Time  Barometric Pressure      Humidity   Temperature  \
# count  86401.000000         86401.000000  86401.000000  86401.000000
# mean   43200.000000           822.635044     25.114295     14.354231
# std    24941.964641             2.466726     15.350057      5.831301
# min        0.000000           818.157241      4.486563      2.610212
# 25%    21600.000000           820.258622     10.202212      8.739184
# 50%    43200.000000           822.606084     25.001702     13.569797
# 75%    64800.000000           824.470893     37.396917     20.138926
# max    86400.000000           827.301068     60.292657     26.744342
#
#        Wind Direction    Wind Speed
# count    86401.000000  86401.000000
# mean       270.421966      4.075831
# std         82.991349      3.041347
# min          1.976088      0.083031
# 25%        215.062650      1.315617
# 50%        254.872175      3.594934
# 75%        330.291338      6.361213
# max        539.468046     17.576875
